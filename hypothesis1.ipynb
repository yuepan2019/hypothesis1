# %%
f = open ('test.txt','r')
text = f.read()
text2 = text.lower()

# %%
import nltk

# %%
#tokens = text2.split()
#print (tokens)
# Out:
# ['“i', 'wish', 'i', 'had', 'a', 'different', 'life.', 'i', 'wish', 'i', 'was', 'braver,', 'and', 'prettier,', 'or', 'just', 'happy.”', '(vardalos,', '2002)', 'all', 'of', 'us', 'have', 'different', 'perceptions', 'of', 'who', 'we', 'are,', 'who', 'we', 'would', 'like', 'to', 'be,', 'and', 'how', 'we', 'want', 'others', 'to', 'view', 'us.', 'there', 'are', 'numerous', 'factors', 'that', 'can', 'influence', 'the', 'self,', 'each', 'one', 'having', 'a', 'different', 'impact', 'than', 'the', 'one', 'before', 'it.', 'one', 'important', 'dynamic', 'is', 'culture.', 'the', 'movie', 'my', 'big', 'fat', 'greek', 'wedding', 'raises', 'several', 'important', 'questions', 'about', 'the', 'relationship', 'between', 'the', 'self', 'and', "one's", 'ethnic', 'background.', 'what', 'effect', 'does', 'being', 'raised', 'in', 'a', 'close-knit', 'collectivistic', 'culture', 'have', 'on', "someone's", 'self-esteem?', 'do', 'people', 'feel', 'it', 'is', 'necessary', 'to', 'change', 'the', 'way', 'in', 'which', 'they', 'portray', 'themselves', 'so', 'they', 'can', 'be', 'accepted', 'into', 'another', 'culture?', 'my', 'big', 'fat', 'greek', 'wedding', 'depicts', 'how', 'culture', 'can', 'shape', 'the', 'self', 'through', 'its', 'influence', 'on', 'autobiographical', 'memories,', 'self-discrepancy,', 'and', 'self-presentation.', 'i', 'can’t', 'do', 'that.', 'i’m', 'happy.']

# %%
from nltk.tokenize import word_tokenize
tokens2 = nltk.word_tokenize(text2)
print (tokens2)
# Out:
# ['“', 'i', 'wish', 'i', 'had', 'a', 'different', 'life', '.', 'i', 'wish', 'i', 'was', 'braver', ',', 'and', 'prettier', ',', 'or', 'just', 'happy.', '”', '(', 'vardalos', ',', '2002', ')', 'all', 'of', 'us', 'have', 'different', 'perceptions', 'of', 'who', 'we', 'are', ',', 'who', 'we', 'would', 'like', 'to', 'be', ',', 'and', 'how', 'we', 'want', 'others', 'to', 'view', 'us', '.', 'there', 'are', 'numerous', 'factors', 'that', 'can', 'influence', 'the', 'self', ',', 'each', 'one', 'having', 'a', 'different', 'impact', 'than', 'the', 'one', 'before', 'it', '.', 'one', 'important', 'dynamic', 'is', 'culture', '.', 'the', 'movie', 'my', 'big', 'fat', 'greek', 'wedding', 'raises', 'several', 'important', 'questions', 'about', 'the', 'relationship', 'between', 'the', 'self', 'and', 'one', "'s", 'ethnic', 'background', '.', 'what', 'effect', 'does', 'being', 'raised', 'in', 'a', 'close-knit', 'collectivistic', 'culture', 'have', 'on', 'someone', "'s", 'self-esteem', '?', 'do', 'people', 'feel', 'it', 'is', 'necessary', 'to', 'change', 'the', 'way', 'in', 'which', 'they', 'portray', 'themselves', 'so', 'they', 'can', 'be', 'accepted', 'into', 'another', 'culture', '?', 'my', 'big', 'fat', 'greek', 'wedding', 'depicts', 'how', 'culture', 'can', 'shape', 'the', 'self', 'through', 'its', 'influence', 'on', 'autobiographical', 'memories', ',', 'self-discrepancy', ',', 'and', 'self-presentation', '.', 'i', 'can', '’', 't', 'do', 'that', '.', 'i', '’', 'm', 'happy', '.']

# %%
words = [word for word in tokens if word.isalpha()]
print(words)
# Out:
# ['i', 'wish', 'i', 'had', 'a', 'different', 'life', 'i', 'wish', 'i', 'was', 'braver', 'and', 'prettier', 'or', 'just', 'vardalos', 'all', 'of', 'us', 'have', 'different', 'perceptions', 'of', 'who', 'we', 'are', 'who', 'we', 'would', 'like', 'to', 'be', 'and', 'how', 'we', 'want', 'others', 'to', 'view', 'us', 'there', 'are', 'numerous', 'factors', 'that', 'can', 'influence', 'the', 'self', 'each', 'one', 'having', 'a', 'different', 'impact', 'than', 'the', 'one', 'before', 'it', 'one', 'important', 'dynamic', 'is', 'culture', 'the', 'movie', 'my', 'big', 'fat', 'greek', 'wedding', 'raises', 'several', 'important', 'questions', 'about', 'the', 'relationship', 'between', 'the', 'self', 'and', 'one', 'ethnic', 'background', 'what', 'effect', 'does', 'being', 'raised', 'in', 'a', 'collectivistic', 'culture', 'have', 'on', 'someone', 'do', 'people', 'feel', 'it', 'is', 'necessary', 'to', 'change', 'the', 'way', 'in', 'which', 'they', 'portray', 'themselves', 'so', 'they', 'can', 'be', 'accepted', 'into', 'another', 'culture', 'my', 'big', 'fat', 'greek', 'wedding', 'depicts', 'how', 'culture', 'can', 'shape', 'the', 'self', 'through', 'its', 'influence', 'on', 'autobiographical', 'memories', 'and', 'i', 'can', 't', 'do', 'that', 'i', 'm', 'happy']

# %%
tok = len(words)
print(tok)
from collections import Counter
counts = Counter(words)
typ =len(counts)
print (typ)
ttr = typ/tok
print(ttr)
# Out:
# 149
# 94
# 0.6308724832214765

# %%
 wnl = nltk.WordNetLemmatizer()
>>> [wnl.lemmatize(t) for t in words]
# Out:
# ['i',
#  'wish',
#  'i',
#  'had',
#  'a',
#  'different',
#  'life',
#  'i',
#  'wish',
#  'i',
#  'wa',
#  'braver',
#  'and',
#  'prettier',
#  'or',
#  'just',
#  'vardalos',
#  'all',
#  'of',
#  'u',
#  'have',
#  'different',
#  'perception',
#  'of',
#  'who',
#  'we',
#  'are',
#  'who',
#  'we',
#  'would',
#  'like',
#  'to',
#  'be',
#  'and',
#  'how',
#  'we',
#  'want',
#  'others',
#  'to',
#  'view',
#  'u',
#  'there',
#  'are',
#  'numerous',
#  'factor',
#  'that',
#  'can',
#  'influence',
#  'the',
#  'self',
#  'each',
#  'one',
#  'having',
#  'a',
#  'different',
#  'impact',
#  'than',
#  'the',
#  'one',
#  'before',
#  'it',
#  'one',
#  'important',
#  'dynamic',
#  'is',
#  'culture',
#  'the',
#  'movie',
#  'my',
#  'big',
#  'fat',
#  'greek',
#  'wedding',
#  'raise',
#  'several',
#  'important',
#  'question',
#  'about',
#  'the',
#  'relationship',
#  'between',
#  'the',
#  'self',
#  'and',
#  'one',
#  'ethnic',
#  'background',
#  'what',
#  'effect',
#  'doe',
#  'being',
#  'raised',
#  'in',
#  'a',
#  'collectivistic',
#  'culture',
#  'have',
#  'on',
#  'someone',
#  'do',
#  'people',
#  'feel',
#  'it',
#  'is',
#  'necessary',
#  'to',
#  'change',
#  'the',
#  'way',
#  'in',
#  'which',
#  'they',
#  'portray',
#  'themselves',
#  'so',
#  'they',
#  'can',
#  'be',
#  'accepted',
#  'into',
#  'another',
#  'culture',
#  'my',
#  'big',
#  'fat',
#  'greek',
#  'wedding',
#  'depicts',
#  'how',
#  'culture',
#  'can',
#  'shape',
#  'the',
#  'self',
#  'through',
#  'it',
#  'influence',
#  'on',
#  'autobiographical',
#  'memory',
#  'and',
#  'i',
#  'can',
#  't',
#  'do',
#  'that',
#  'i',
#  'm',
#  'happy']

# %%
porter = nltk.PorterStemmer()
>>> [porter.stem(t) for t in tokens]
# Out:
# ['“i',
#  'wish',
#  'i',
#  'had',
#  'a',
#  'differ',
#  'life.',
#  'i',
#  'wish',
#  'i',
#  'wa',
#  'braver,',
#  'and',
#  'prettier,',
#  'or',
#  'just',
#  'happy.”',
#  '(vardalos,',
#  '2002)',
#  'all',
#  'of',
#  'us',
#  'have',
#  'differ',
#  'percept',
#  'of',
#  'who',
#  'we',
#  'are,',
#  'who',
#  'we',
#  'would',
#  'like',
#  'to',
#  'be,',
#  'and',
#  'how',
#  'we',
#  'want',
#  'other',
#  'to',
#  'view',
#  'us.',
#  'there',
#  'are',
#  'numer',
#  'factor',
#  'that',
#  'can',
#  'influenc',
#  'the',
#  'self,',
#  'each',
#  'one',
#  'have',
#  'a',
#  'differ',
#  'impact',
#  'than',
#  'the',
#  'one',
#  'befor',
#  'it.',
#  'one',
#  'import',
#  'dynam',
#  'is',
#  'culture.',
#  'the',
#  'movi',
#  'my',
#  'big',
#  'fat',
#  'greek',
#  'wed',
#  'rais',
#  'sever',
#  'import',
#  'question',
#  'about',
#  'the',
#  'relationship',
#  'between',
#  'the',
#  'self',
#  'and',
#  "one'",
#  'ethnic',
#  'background.',
#  'what',
#  'effect',
#  'doe',
#  'be',
#  'rais',
#  'in',
#  'a',
#  'close-knit',
#  'collectivist',
#  'cultur',
#  'have',
#  'on',
#  "someone'",
#  'self-esteem?',
#  'do',
#  'peopl',
#  'feel',
#  'it',
#  'is',
#  'necessari',
#  'to',
#  'chang',
#  'the',
#  'way',
#  'in',
#  'which',
#  'they',
#  'portray',
#  'themselv',
#  'so',
#  'they',
#  'can',
#  'be',
#  'accept',
#  'into',
#  'anoth',
#  'culture?',
#  'my',
#  'big',
#  'fat',
#  'greek',
#  'wed',
#  'depict',
#  'how',
#  'cultur',
#  'can',
#  'shape',
#  'the',
#  'self',
#  'through',
#  'it',
#  'influenc',
#  'on',
#  'autobiograph',
#  'memories,',
#  'self-discrepancy,',
#  'and',
#  'self-presentation.',
#  'i',
#  'can’t',
#  'do',
#  'that.',
#  'i’m',
#  'happy.']
